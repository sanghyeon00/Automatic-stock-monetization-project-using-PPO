# %% [markdown]
# #

# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = [
    "MSFT"
]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df['ticker'] = ticker  # 티커 열 추가

    # 이동 평균 (Moving Average)

    # 상대 강도 지수 (RSI: Relative Strength Index)
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # MACD (Moving Average Convergence Divergence)
    macd = ta.trend.MACD(df['Close'])

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['BB_High'] = bollinger.bollinger_hband()
    df['BB_Low'] = bollinger.bollinger_lband()
    df['BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    df['RSI'].fillna(df['RSI'].mean(), inplace=True)
    df['BB_High'].fillna(df['BB_High'].mean(), inplace=True)
    df['BB_Low'].fillna(df['BB_Low'].mean(), inplace=True)
    df['BB_Middle'].fillna(df['BB_Middle'].mean(), inplace=True)

    data[ticker] = df

# 여러 데이터프레임을 하나로 결합
combined_df = pd.concat(data.values(), ignore_index=False)

# 필요한 열 선택 (모든 feature 포함)
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'BB_High', 'BB_Low', 'BB_Middle', 'ticker']
combined_df = combined_df[features]

# 'Date'를 인덱스로 설정 (필요한 경우)
combined_df.index.name = 'Date'

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
print
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#                  Open       High        Low      Close    Volume        RSI  \
# Date
# 2018-01-02  86.129997  86.309998  85.500000  85.949997  22483800  55.421975
# 2018-01-03  86.059998  86.510002  85.970001  86.349998  26061400  55.421975
# 2018-01-04  86.589996  87.660004  86.570000  87.110001  21912000  55.421975
# 2018-01-05  87.660004  88.410004  87.430000  88.190002  23407100  55.421975
# 2018-01-08  88.199997  88.580002  87.599998  88.279999  22113000  55.421975
#
#                BB_High      BB_Low   BB_Middle ticker
# Date
# 2018-01-02  224.839154  202.259292  213.549223   MSFT
# 2018-01-03  224.839154  202.259292  213.549223   MSFT
# 2018-01-04  224.839154  202.259292  213.549223   MSFT
# 2018-01-05  224.839154  202.259292  213.549223   MSFT
# 2018-01-08  224.839154  202.259292  213.549223   MSFT
# Test Set:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-03-14  280.339996  285.399994  275.820007  276.440002  30660700
# 2022-03-15  280.350006  287.820007  278.730011  287.149994  34245100
# 2022-03-16  289.109985  294.570007  283.200012  294.390015  37826300
# 2022-03-17  293.290009  295.609985  289.369995  295.220001  30816600
# 2022-03-18  295.369995  301.000000  292.730011  300.429993  43390600
#
#                   RSI     BB_High      BB_Low   BB_Middle ticker
# Date
# 2022-03-14  38.612553  305.879554  273.979448  289.929501   MSFT
# 2022-03-15  46.721340  305.354432  273.719571  289.537001   MSFT
# 2022-03-16  51.395349  304.419367  274.046636  289.233002   MSFT
# 2022-03-17  51.916126  303.733929  274.304074  289.019002   MSFT
# 2022-03-18  55.163666  305.029619  273.978382  289.504001   MSFT

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df = df.drop(columns=['ticker'])  # ticker 열 제거
        self.action_space = spaces.Discrete(3)  # Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(len(self.df.columns),), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = []
        self.balance = self.initial_balance
        self.state = self.df.iloc[self.current_step].values
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df) - 1
        reward = 0
        additional_reward = 0

        if action == 0 and not self.done:  # Buy
            if self.balance >= self.state[3]:  # Check if balance is sufficient to buy
                self.inventory.append(self.state[3])  # Close price
                self.balance -= self.state[3]

        elif action == 1 and not self.done:  # Sell
            if len(self.inventory) > 0:
                bought_price = self.inventory.pop(0)
                reward = self.state[3] - bought_price  # Current price - Bought price
                self.total_profit += reward
                self.balance += self.state[3]

        # 추가된 보상 요소들
        if self.state[5] >= 70 and action == 1:  # RSI가 70 이상일 때 매도
            additional_reward += 1
        elif self.state[5] <= 30 and action == 0:  # RSI가 30 이하일 때 매수
            additional_reward += 1

        if self.state[3] >= self.state[6] and action == 1:  # 주가가 BB 상한선 이상일 때 매도
            additional_reward += 1
        elif self.state[3] <= self.state[7] and action == 0:  # 주가가 BB 하한선 이하일 때 매수
            additional_reward += 1

        if self.state[4] > self.df['Volume'].mean() and (action == 0 or action == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
            additional_reward += 1

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.5
        drawdown_scale = 0.5

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = self.df.iloc[self.current_step].values
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')


class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        self.action_distribution.append(self.locals["actions"])
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()

# 데이터 로드 및 train/test 분할
train_df, test_df = train_test_split(df, test_size=0.3, shuffle=False)

# 학습 환경 설정
train_env = DummyVecEnv([lambda: StockTradingEnv(train_df)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "./ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure("/ppo_stock_trading_v11/", ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./MSFT/MSFT_Checkpoint_6/',
                                         name_prefix='ppo_stock_trading')

# PPO 모델 학습
# model = PPO('MlpPolicy', train_env, learning_rate=0.0003, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, verbose=1, device=device)
model = PPO('MlpPolicy', train_env, verbose=1, device=device)

model.set_logger(new_logger)

#stable_baselines3' 모듈에 임시로 '__version__' 속성을 추가합니다.
# import stable_baselines3 as sb3
# sb3_version = "1.0.0"

model.learn(total_timesteps=200000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")

# TensorBoard 로그 파일을 로컬에서 실행
# !tensorboard --logdir ./ppo_stock_trading
# Out:
# Logging to /ppo_stock_trading_v11/
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | 0.738    |
# | time/              |          |
# |    fps             | 575      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 2           |
# |    episode_reward       | 1.37        |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012892024 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.16e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 1.97e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 3           |
# |    episode_reward       | 1.04        |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012271211 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 221         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000874   |
# |    value_loss           | 1.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 4           |
# |    episode_reward       | 1.72        |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011837691 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 448         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 5           |
# |    episode_reward       | 8.45        |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017428594 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 166         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00758    |
# |    value_loss           | 462         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 6            |
# |    episode_reward       | 9.34         |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 6            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0070013814 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.1         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00786     |
# |    value_loss           | 236          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 7           |
# |    episode_reward       | 14.8        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 7           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008010378 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 296         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 8           |
# |    episode_reward       | 27.5        |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 8           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008007872 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0097     |
# |    value_loss           | 280         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 9            |
# |    episode_reward       | 29.5         |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 9            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0037252172 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 286          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 10           |
# |    episode_reward       | 31.5         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 10           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0046973396 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 315          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 11           |
# |    episode_reward       | 33.5         |
# | time/                   |              |
# |    fps                  | 455          |
# |    iterations           | 11           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0019963356 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 95.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 321          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 12           |
# |    episode_reward       | 35.5         |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 12           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0037225941 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.424       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.9         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 275          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 13          |
# |    episode_reward       | 37.5        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 13          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.002841475 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 143         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 285         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 14           |
# |    episode_reward       | 39.6         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 14           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0017482359 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 100          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 289          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 15           |
# |    episode_reward       | 41.6         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 15           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0021466864 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.315       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 241          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 16           |
# |    episode_reward       | 44.1         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 16           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0027706854 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.7         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 246          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 17          |
# |    episode_reward       | 46          |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 17          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002191105 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.227      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 220         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 18           |
# |    episode_reward       | 48           |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 18           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0014159295 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.198       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43           |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 188          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 19           |
# |    episode_reward       | 48           |
# | time/                   |              |
# |    fps                  | 462          |
# |    iterations           | 19           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0012333975 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.2         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 251          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 20           |
# |    episode_reward       | 50           |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 20           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0009722337 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.122       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.6         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 209          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 21            |
# |    episode_reward       | 52            |
# | time/                   |               |
# |    fps                  | 464           |
# |    iterations           | 21            |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00050022267 |
# |    clip_fraction        | 0.00991       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.11         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 77.1          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000546     |
# |    value_loss           | 206           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 22           |
# |    episode_reward       | 54.2         |
# | time/                   |              |
# |    fps                  | 464          |
# |    iterations           | 22           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 4.770598e-05 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0891      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 250          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000549    |
# |    value_loss           | 239          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 23            |
# |    episode_reward       | 56.2          |
# | time/                   |               |
# |    fps                  | 465           |
# |    iterations           | 23            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00021015259 |
# |    clip_fraction        | 0.00215       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0837       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 102           |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000165     |
# |    value_loss           | 251           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 24           |
# |    episode_reward       | 58.2         |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 24           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0002907786 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0722      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 165          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000163    |
# |    value_loss           | 206          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 25           |
# |    episode_reward       | 60.3         |
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 25           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 1.924779e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0744      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -2.23e-05    |
# |    value_loss           | 255          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 26           |
# |    episode_reward       | 62.8         |
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 26           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0007141222 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0588      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 244          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000328     |
# |    value_loss           | 232          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 27            |
# |    episode_reward       | 65            |
# | time/                   |               |
# |    fps                  | 465           |
# |    iterations           | 27            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00054819835 |
# |    clip_fraction        | 0.00269       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0591       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 282           |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000314     |
# |    value_loss           | 264           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 28          |
# |    episode_reward       | 67          |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 28          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.000259836 |
# |    clip_fraction        | 0.00288     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0466     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 511         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -2.18e-05   |
# |    value_loss           | 261         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 29            |
# |    episode_reward       | 69.1          |
# | time/                   |               |
# |    fps                  | 462           |
# |    iterations           | 29            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00017397091 |
# |    clip_fraction        | 0.00146       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.04         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 130           |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000149     |
# |    value_loss           | 295           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 30           |
# |    episode_reward       | 71.6         |
# | time/                   |              |
# |    fps                  | 462          |
# |    iterations           | 30           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0040881853 |
# |    clip_fraction        | 0.00405      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0346      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 244          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000442    |
# |    value_loss           | 288          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 31           |
# |    episode_reward       | 74.1         |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 31           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0001516733 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0208      |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 118          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -2.55e-05    |
# |    value_loss           | 277          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 32           |
# |    episode_reward       | 76.6         |
# | time/                   |              |
# |    fps                  | 462          |
# |    iterations           | 32           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 8.360512e-05 |
# |    clip_fraction        | 0.00215      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0245      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.7         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -6.62e-05    |
# |    value_loss           | 321          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 33            |
# |    episode_reward       | 79.1          |
# | time/                   |               |
# |    fps                  | 462           |
# |    iterations           | 33            |
# |    time_elapsed         | 146           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00029719734 |
# |    clip_fraction        | 0.00127       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0236       |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 65.7          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000215     |
# |    value_loss           | 314           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 34            |
# |    episode_reward       | 81.2          |
# | time/                   |               |
# |    fps                  | 462           |
# |    iterations           | 34            |
# |    time_elapsed         | 150           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 4.2351254e-05 |
# |    clip_fraction        | 0.000732      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.021        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 30.1          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | 4.68e-06      |
# |    value_loss           | 327           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 35           |
# |    episode_reward       | 83.2         |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 35           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 3.003722e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0206      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -3.78e-05    |
# |    value_loss           | 186          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 36           |
# |    episode_reward       | 85.2         |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 36           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 7.174947e-05 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0129      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.2         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000143    |
# |    value_loss           | 328          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 37            |
# |    episode_reward       | 87.7          |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 37            |
# |    time_elapsed         | 163           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 2.9277784e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0149       |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 58.4          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -3.2e-05      |
# |    value_loss           | 340           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 38            |
# |    episode_reward       | 90.2          |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 38            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 2.4889305e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0119       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 14.3          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -8.56e-06     |
# |    value_loss           | 362           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 39            |
# |    episode_reward       | 92.7          |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 39            |
# |    time_elapsed         | 172           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 3.1548552e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0114       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 179           |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 3.37e-07      |
# |    value_loss           | 353           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 40            |
# |    episode_reward       | 95.2          |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 40            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 4.3549342e-05 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0107       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 15.9          |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000225     |
# |    value_loss           | 364           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 41            |
# |    episode_reward       | 97.7          |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 41            |
# |    time_elapsed         | 181           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 4.8195943e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0102       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 192           |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 1.28e-05      |
# |    value_loss           | 373           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 42            |
# |    episode_reward       | 100           |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 42            |
# |    time_elapsed         | 185           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 2.5809422e-05 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00797      |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 393           |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000253     |
# |    value_loss           | 388           |
# -------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    episode_length       | 43       |
# |    episode_reward       | 103      |
# | time/                   |          |
# |    fps                  | 462      |
# |    iterations           | 43       |
# |    time_elapsed         | 190      |
# |    total_timesteps      | 88064    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00768 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 54.6     |
# |    n_updates            | 420      |
# |    policy_gradient_loss | -1.5e-09 |
# |    value_loss           | 389      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    episode_length       | 44       |
# |    episode_reward       | 105      |
# | time/                   |          |
# |    fps                  | 462      |
# |    iterations           | 44       |
# |    time_elapsed         | 194      |
# |    total_timesteps      | 90112    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00768 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 34.6     |
# |    n_updates            | 430      |
# |    policy_gradient_loss | 7.81e-09 |
# |    value_loss           | 395      |
# --------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 45            |
# |    episode_reward       | 108           |
# | time/                   |               |
# |    fps                  | 462           |
# |    iterations           | 45            |
# |    time_elapsed         | 199           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.6396196e-05 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00882      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 301           |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -6.02e-06     |
# |    value_loss           | 415           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 46            |
# |    episode_reward       | 110           |
# | time/                   |               |
# |    fps                  | 461           |
# |    iterations           | 46            |
# |    time_elapsed         | 203           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00021691713 |
# |    clip_fraction        | 0.0019        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00696      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 11.1          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -4.87e-05     |
# |    value_loss           | 414           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 47            |
# |    episode_reward       | 113           |
# | time/                   |               |
# |    fps                  | 460           |
# |    iterations           | 47            |
# |    time_elapsed         | 209           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 2.4590612e-05 |
# |    clip_fraction        | 0.000732      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00778      |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 336           |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -2.9e-05      |
# |    value_loss           | 401           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 48        |
# |    episode_reward       | 115       |
# | time/                   |           |
# |    fps                  | 458       |
# |    iterations           | 48        |
# |    time_elapsed         | 214       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00817  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 190       |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -1.03e-08 |
# |    value_loss           | 407       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 49           |
# |    episode_reward       | 118          |
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 49           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 8.931209e-06 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00887     |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -6.12e-06    |
# |    value_loss           | 411          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 50            |
# |    episode_reward       | 120           |
# | time/                   |               |
# |    fps                  | 454           |
# |    iterations           | 50            |
# |    time_elapsed         | 225           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 7.8090554e-05 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00883      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 631           |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -4.21e-06     |
# |    value_loss           | 414           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 51            |
# |    episode_reward       | 123           |
# | time/                   |               |
# |    fps                  | 453           |
# |    iterations           | 51            |
# |    time_elapsed         | 230           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00021775306 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00475      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 170           |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -6.36e-05     |
# |    value_loss           | 213           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 52        |
# |    episode_reward       | 125       |
# | time/                   |           |
# |    fps                  | 451       |
# |    iterations           | 52        |
# |    time_elapsed         | 235       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00452  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 35.4      |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -4.86e-08 |
# |    value_loss           | 424       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    episode_length       | 53       |
# |    episode_reward       | 128      |
# | time/                   |          |
# |    fps                  | 450      |
# |    iterations           | 53       |
# |    time_elapsed         | 241      |
# |    total_timesteps      | 108544   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00452 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 6.11     |
# |    n_updates            | 520      |
# |    policy_gradient_loss | 1.83e-08 |
# |    value_loss           | 428      |
# --------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 54            |
# |    episode_reward       | 130           |
# | time/                   |               |
# |    fps                  | 448           |
# |    iterations           | 54            |
# |    time_elapsed         | 246           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00014749277 |
# ...
# |    fps                  | 390       |
# |    iterations           | 81        |
# |    time_elapsed         | 424       |
# |    total_timesteps      | 165888    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00156  |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 62.2      |
# |    n_updates            | 800       |
# |    policy_gradient_loss | -3.54e-09 |
# |    value_loss           | 436       |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 82            |
# |    episode_reward       | 200           |
# | time/                   |               |
# |    fps                  | 390           |
# |    iterations           | 82            |
# |    time_elapsed         | 430           |
# |    total_timesteps      | 167936        |
# | train/                  |               |
# |    approx_kl            | 0.00025686214 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000658     |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 159           |
# |    n_updates            | 810           |
# |    policy_gradient_loss | -0.000368     |
# |    value_loss           | 440           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 83        |
# |    episode_reward       | 202       |
# | time/                   |           |
# |    fps                  | 389       |
# |    iterations           | 83        |
# |    time_elapsed         | 436       |
# |    total_timesteps      | 169984    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 82.8      |
# |    n_updates            | 820       |
# |    policy_gradient_loss | 2.29e-09  |
# |    value_loss           | 436       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 84        |
# |    episode_reward       | 205       |
# | time/                   |           |
# |    fps                  | 387       |
# |    iterations           | 84        |
# |    time_elapsed         | 444       |
# |    total_timesteps      | 172032    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 386       |
# |    n_updates            | 830       |
# |    policy_gradient_loss | -6.51e-09 |
# |    value_loss           | 222       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 85        |
# |    episode_reward       | 207       |
# | time/                   |           |
# |    fps                  | 384       |
# |    iterations           | 85        |
# |    time_elapsed         | 452       |
# |    total_timesteps      | 174080    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 370       |
# |    n_updates            | 840       |
# |    policy_gradient_loss | -1.01e-08 |
# |    value_loss           | 439       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 86        |
# |    episode_reward       | 210       |
# | time/                   |           |
# |    fps                  | 383       |
# |    iterations           | 86        |
# |    time_elapsed         | 459       |
# |    total_timesteps      | 176128    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 328       |
# |    n_updates            | 850       |
# |    policy_gradient_loss | -5.76e-09 |
# |    value_loss           | 441       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 87        |
# |    episode_reward       | 212       |
# | time/                   |           |
# |    fps                  | 381       |
# |    iterations           | 87        |
# |    time_elapsed         | 467       |
# |    total_timesteps      | 178176    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.24      |
# |    n_updates            | 860       |
# |    policy_gradient_loss | -1.4e-08  |
# |    value_loss           | 441       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 88        |
# |    episode_reward       | 215       |
# | time/                   |           |
# |    fps                  | 379       |
# |    iterations           | 88        |
# |    time_elapsed         | 474       |
# |    total_timesteps      | 180224    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 57.8      |
# |    n_updates            | 870       |
# |    policy_gradient_loss | 2.12e-10  |
# |    value_loss           | 439       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 89        |
# |    episode_reward       | 217       |
# | time/                   |           |
# |    fps                  | 377       |
# |    iterations           | 89        |
# |    time_elapsed         | 482       |
# |    total_timesteps      | 182272    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.22      |
# |    n_updates            | 880       |
# |    policy_gradient_loss | -3.2e-11  |
# |    value_loss           | 439       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 90        |
# |    episode_reward       | 220       |
# | time/                   |           |
# |    fps                  | 377       |
# |    iterations           | 90        |
# |    time_elapsed         | 488       |
# |    total_timesteps      | 184320    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 199       |
# |    n_updates            | 890       |
# |    policy_gradient_loss | 3.67e-10  |
# |    value_loss           | 438       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 91        |
# |    episode_reward       | 222       |
# | time/                   |           |
# |    fps                  | 376       |
# |    iterations           | 91        |
# |    time_elapsed         | 494       |
# |    total_timesteps      | 186368    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000582 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 788       |
# |    n_updates            | 900       |
# |    policy_gradient_loss | 9.02e-11  |
# |    value_loss           | 438       |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    episode_length       | 92            |
# |    episode_reward       | 225           |
# | time/                   |               |
# |    fps                  | 375           |
# |    iterations           | 92            |
# |    time_elapsed         | 502           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 5.7468424e-07 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000544     |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 368           |
# |    n_updates            | 910           |
# |    policy_gradient_loss | 1.04e-05      |
# |    value_loss           | 437           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 93        |
# |    episode_reward       | 227       |
# | time/                   |           |
# |    fps                  | 373       |
# |    iterations           | 93        |
# |    time_elapsed         | 509       |
# |    total_timesteps      | 190464    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00062  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 102       |
# |    n_updates            | 920       |
# |    policy_gradient_loss | -3.41e-09 |
# |    value_loss           | 437       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 94        |
# |    episode_reward       | 230       |
# | time/                   |           |
# |    fps                  | 372       |
# |    iterations           | 94        |
# |    time_elapsed         | 517       |
# |    total_timesteps      | 192512    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00062  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.73      |
# |    n_updates            | 930       |
# |    policy_gradient_loss | -5.16e-09 |
# |    value_loss           | 436       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 95        |
# |    episode_reward       | 232       |
# | time/                   |           |
# |    fps                  | 370       |
# |    iterations           | 95        |
# |    time_elapsed         | 525       |
# |    total_timesteps      | 194560    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00062  |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 83        |
# |    n_updates            | 940       |
# |    policy_gradient_loss | 9.08e-10  |
# |    value_loss           | 436       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    episode_length       | 96       |
# |    episode_reward       | 235      |
# | time/                   |          |
# |    fps                  | 368      |
# |    iterations           | 96       |
# |    time_elapsed         | 533      |
# |    total_timesteps      | 196608   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00062 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 160      |
# |    n_updates            | 950      |
# |    policy_gradient_loss | 1.76e-09 |
# |    value_loss           | 435      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    episode_length       | 97       |
# |    episode_reward       | 237      |
# | time/                   |          |
# |    fps                  | 367      |
# |    iterations           | 97       |
# |    time_elapsed         | 541      |
# |    total_timesteps      | 198656   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00062 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 192      |
# |    n_updates            | 960      |
# |    policy_gradient_loss | 1.68e-09 |
# |    value_loss           | 436      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 98        |
# |    episode_reward       | 240       |
# | time/                   |           |
# |    fps                  | 365       |
# |    iterations           | 98        |
# |    time_elapsed         | 548       |
# |    total_timesteps      | 200704    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00062  |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 104       |
# |    n_updates            | 970       |
# |    policy_gradient_loss | -2.39e-09 |
# |    value_loss           | 436       |
# ---------------------------------------
# Mean episode reward: 2.4471642444841564
# Mean episode length: 1.0
# Cumulative reward: 239.82209595944732
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Balance: 100000
# Total Profit: 0
# Total Rewards: 1131.7312072646241
# Total Additional Rewards: 906
# Total Stability Bonus: 225.73120726462363
# profit: 4.831690603168681e-13

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 테스트 환경 설정
test_df = df  # 테스트용 데이터프레임 설정 (기존 데이터프레임 사용)
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './MSFT/MSFT_Checkpoint_6/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)

    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    total_stability_bonus = 0
    done = False

    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']
        total_stability_bonus += info[0]['stability_bonus']

    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_additional_rewards': total_additional_rewards,
        'total_stability_bonus': total_stability_bonus,
        'total_profit': total_rewards - total_additional_rewards - total_stability_bonus,
    })

# 결과 출력
for result in results:
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_rewards']}")
    print(f"total_additional_rewards: {result['total_additional_rewards']}")
    print(f"Total Stability_bonus: {result['total_stability_bonus']}")
    print(f"Total Profit: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_100000_steps.zip
# Total Rewards: 3430.3458687969546
# total_additional_rewards: 3016
# Total Stability_bonus: 405.1058480450043
# Total Profit: 9.24002075195034
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_120000_steps.zip
# Total Rewards: 3768.8055136239996
# total_additional_rewards: 3016
# Total Stability_bonus: 752.8055136239991
# Total Profit: 4.547473508864641e-13
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_140000_steps.zip
# Total Rewards: 3771.731207264624
# total_additional_rewards: 3018
# Total Stability_bonus: 753.7312072646237
# Total Profit: 4.547473508864641e-13
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_160000_steps.zip
# Total Rewards: 3771.731207264624
# total_additional_rewards: 3018
# Total Stability_bonus: 753.7312072646237
# Total Profit: 4.547473508864641e-13
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_180000_steps.zip
# Total Rewards: 3771.731207264624
# total_additional_rewards: 3018
# Total Stability_bonus: 753.7312072646237
# Total Profit: 4.547473508864641e-13
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_200000_steps.zip
# Total Rewards: 3771.731207264624
# total_additional_rewards: 3018
# Total Stability_bonus: 753.7312072646237
# Total Profit: 4.547473508864641e-13
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_20000_steps.zip
# Total Rewards: 2718.7628456920133
# total_additional_rewards: 2713
# Total Stability_bonus: -9.427255931517859
# Total Profit: 15.190101623531202
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_40000_steps.zip
# Total Rewards: 3098.6781364231424
# total_additional_rewards: 2964
# Total Stability_bonus: 125.81816633036723
# Total Profit: 8.859970092775171
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_60000_steps.zip
# Total Rewards: 3771.731207264624
# total_additional_rewards: 3018
# Total Stability_bonus: 753.7312072646237
# Total Profit: 4.547473508864641e-13
# ==================================================
# Checkpoint: ./MSFT/MSFT_Checkpoint_6/ppo_stock_trading_80000_steps.zip
# Total Rewards: 3627.821946453889
# total_additional_rewards: 3017
# Total Stability_bonus: 604.8519452331909
# Total Profit: 5.970001220697895
# ==================================================
