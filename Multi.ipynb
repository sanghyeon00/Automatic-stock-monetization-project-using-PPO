# %%
import yfinance as yf
import pandas as pd
import ta  # Technical Analysis library
from sklearn.model_selection import train_test_split

# 사용할 주식 티커 목록
tickers = ["AAPL", "SCHW", "MSFT"]

data = {}

# 각 티커에 대해 데이터를 다운로드하고 데이터프레임에 저장
for ticker in tickers:
    df = yf.download(ticker, start='2018-01-01', end='2024-01-01')
    df.rename(columns={
        'Open': f'{ticker}_Open',
        'High': f'{ticker}_High',
        'Low': f'{ticker}_Low',
        'Close': f'{ticker}_Close',
        'Volume': f'{ticker}_Volume',
        'Adj Close': f'{ticker}_Adj_Close'
    }, inplace=True)
    df[f'{ticker}_ticker'] = ticker  # 티커 열 추가
    data[ticker] = df

# 데이터프레임을 동일한 날짜 인덱스로 결합
combined_df = pd.concat(data.values(), axis=1)

# 결합된 데이터프레임에 기술 지표 추가
for ticker in tickers:
    # 상대 강도 지수 (RSI: Relative Strength Index)
    combined_df[f'{ticker}_RSI'] = ta.momentum.RSIIndicator(combined_df[f'{ticker}_Close'], window=14).rsi()

    # 볼린저 밴드 (Bollinger Bands)
    bollinger = ta.volatility.BollingerBands(combined_df[f'{ticker}_Close'], window=20, window_dev=2)
    combined_df[f'{ticker}_BB_High'] = bollinger.bollinger_hband()
    combined_df[f'{ticker}_BB_Low'] = bollinger.bollinger_lband()
    combined_df[f'{ticker}_BB_Middle'] = bollinger.bollinger_mavg()

    # NaN 값을 각 feature의 평균으로 대체
    combined_df[f'{ticker}_RSI'].fillna(combined_df[f'{ticker}_RSI'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_High'].fillna(combined_df[f'{ticker}_BB_High'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_Low'].fillna(combined_df[f'{ticker}_BB_Low'].mean(), inplace=True)
    combined_df[f'{ticker}_BB_Middle'].fillna(combined_df[f'{ticker}_BB_Middle'].mean(), inplace=True)

# 필요한 열 선택 (모든 feature 포함)
features = []
for ticker in tickers:
    features.extend([f'{ticker}_Open', f'{ticker}_High', f'{ticker}_Low', f'{ticker}_Close', f'{ticker}_Volume', f'{ticker}_RSI', f'{ticker}_BB_High', f'{ticker}_BB_Low', f'{ticker}_BB_Middle', f'{ticker}_ticker'])

combined_df = combined_df[features]

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df, test_df = train_test_split(combined_df, test_size=0.3, shuffle=False)

# 'Date'를 인덱스로 설정 (필요한 경우)
train_df.index.name = 'Date'
test_df.index.name = 'Date'

print("Train Set:")
print(train_df.head())
print("Test Set:")
print(test_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Train Set:
#             AAPL_Open  AAPL_High   AAPL_Low  AAPL_Close  AAPL_Volume  \
# Date
# 2018-01-02  42.540001  43.075001  42.314999   43.064999    102223600
# 2018-01-03  43.132500  43.637501  42.990002   43.057499    118071600
# 2018-01-04  43.134998  43.367500  43.020000   43.257500     89738400
# 2018-01-05  43.360001  43.842499  43.262501   43.750000     94640000
# 2018-01-08  43.587502  43.902500  43.482498   43.587502     82271200
#
#              AAPL_RSI  AAPL_BB_High  AAPL_BB_Low  AAPL_BB_Middle AAPL_ticker  \
# Date
# 2018-01-02  55.464422    117.022959   103.611428      110.317193        AAPL
# 2018-01-03  55.464422    117.022959   103.611428      110.317193        AAPL
# 2018-01-04  55.464422    117.022959   103.611428      110.317193        AAPL
# 2018-01-05  55.464422    117.022959   103.611428      110.317193        AAPL
# 2018-01-08  55.464422    117.022959   103.611428      110.317193        AAPL
#
#             ...  MSFT_Open  MSFT_High   MSFT_Low  MSFT_Close  MSFT_Volume  \
# Date        ...
# 2018-01-02  ...  86.129997  86.309998  85.500000   85.949997     22483800
# 2018-01-03  ...  86.059998  86.510002  85.970001   86.349998     26061400
# 2018-01-04  ...  86.589996  87.660004  86.570000   87.110001     21912000
# 2018-01-05  ...  87.660004  88.410004  87.430000   88.190002     23407100
# 2018-01-08  ...  88.199997  88.580002  87.599998   88.279999     22113000
#
#              MSFT_RSI  MSFT_BB_High  MSFT_BB_Low  MSFT_BB_Middle MSFT_ticker
# Date
# 2018-01-02  55.421975    224.839154   202.259292      213.549223        MSFT
# 2018-01-03  55.421975    224.839154   202.259292      213.549223        MSFT
# 2018-01-04  55.421975    224.839154   202.259292      213.549223        MSFT
# 2018-01-05  55.421975    224.839154   202.259292      213.549223        MSFT
# 2018-01-08  55.421975    224.839154   202.259292      213.549223        MSFT
#
# [5 rows x 30 columns]
# Test Set:
#              AAPL_Open   AAPL_High    AAPL_Low  AAPL_Close  AAPL_Volume  \
# Date
# 2022-03-14  151.449997  154.119995  150.100006  150.619995    108732100
# 2022-03-15  150.899994  155.570007  150.380005  155.089996     92964300
# 2022-03-16  157.050003  160.000000  154.460007  159.589996    102300200
# 2022-03-17  158.610001  161.000000  157.630005  160.619995     75615400
# 2022-03-18  160.509995  164.479996  159.759995  163.979996    123511700
#
#              AAPL_RSI  AAPL_BB_High  AAPL_BB_Low  AAPL_BB_Middle AAPL_ticker  \
# Date
# 2022-03-14  32.534970    174.440631   152.581371      163.511001        AAPL
# 2022-03-15  39.742195    174.045252   151.597749      162.821500        AAPL
# 2022-03-16  45.996781    172.478697   151.844304      162.161501        AAPL
# 2022-03-17  47.344011    170.725368   152.404632      161.565000        AAPL
# 2022-03-18  51.586997    169.930274   152.709725      161.320000        AAPL
#
#             ...   MSFT_Open   MSFT_High    MSFT_Low  MSFT_Close  MSFT_Volume  \
# Date        ...
# 2022-03-14  ...  280.339996  285.399994  275.820007  276.440002     30660700
# 2022-03-15  ...  280.350006  287.820007  278.730011  287.149994     34245100
# 2022-03-16  ...  289.109985  294.570007  283.200012  294.390015     37826300
# 2022-03-17  ...  293.290009  295.609985  289.369995  295.220001     30816600
# 2022-03-18  ...  295.369995  301.000000  292.730011  300.429993     43390600
#
#              MSFT_RSI  MSFT_BB_High  MSFT_BB_Low  MSFT_BB_Middle MSFT_ticker
# Date
# 2022-03-14  38.612553    305.879554   273.979448      289.929501        MSFT
# 2022-03-15  46.721340    305.354432   273.719571      289.537001        MSFT
# 2022-03-16  51.395349    304.419367   274.046636      289.233002        MSFT
# 2022-03-17  51.916126    303.733929   274.304074      289.019002        MSFT
# 2022-03-18  55.163666    305.029619   273.978382      289.504001        MSFT
#
# [5 rows x 30 columns]

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import configure
import torch
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

cumu_lst = []
cumu_hap = 0

class StockTradingEnv(gym.Env):
    global cumu_lst, cumu_hap
    metadata = {'render.modes': ['human']}

    def __init__(self, df_list, initial_balance=100000):
        super(StockTradingEnv, self).__init__()

        self.df_list = [df.drop(columns=[col for col in df.columns if 'ticker' in col]) for df in df_list]  # ticker 열 제거
        self.n_stocks = len(df_list)
        self.action_space = spaces.MultiDiscrete([3] * self.n_stocks)  # 각 주식에 대해 Buy, Hold, Sell
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.n_stocks, len(self.df_list[0].columns)), dtype=np.float32)

        self.initial_balance = initial_balance
        self.reset()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.total_profit = 0
        self.inventory = [[] for _ in range(self.n_stocks)]
        self.balance = self.initial_balance
        self.state = np.array([df.iloc[self.current_step].values for df in self.df_list])
        self.returns = [0]

        return self.state

    def step(self, action):
        global cumu_lst
        self.done = self.current_step >= len(self.df_list[0]) - 1
        reward = 0
        additional_reward = 0

        for i, act in enumerate(action):
            if act == 0 and not self.done:  # Buy
                if self.balance >= self.state[i][3]:  # Check if balance is sufficient to buy
                    self.inventory[i].append(self.state[i][3])  # Close price
                    self.balance -= self.state[i][3]

            elif act == 1 and not self.done:  # Sell
                if len(self.inventory[i]) > 0:
                    bought_price = self.inventory[i].pop(0)
                    reward += self.state[i][3] - bought_price  # Current price - Bought price
                    self.total_profit += reward
                    self.balance += self.state[i][3]

            # 추가된 보상 요소들
            if self.state[i][5] >= 70 and act == 1:  # RSI가 70 이상일 때 매도
                additional_reward += 0.1
            elif self.state[i][5] <= 30 and act == 0:  # RSI가 30 이하일 때 매수
                additional_reward += 0.1

            if self.state[i][3] >= self.state[i][6] and act == 1:  # 주가가 BB 상한선 이상일 때 매도
                additional_reward += 0.1
            elif self.state[i][3] <= self.state[i][7] and act == 0:  # 주가가 BB 하한선 이하일 때 매수
                additional_reward += 0.1

            if self.state[i][4] > self.df_list[i].iloc[:, 4].mean() and (act == 0 or act == 1):  # 거래량이 평균 이상일 때 매수 또는 매도
                additional_reward += 0.1

        total_reward = reward + additional_reward

        # Sharpe Ratio
        if len(self.returns) > 1:
            sharpe_ratio = np.mean(self.returns) / (np.std(self.returns) + 1e-10)
        else:
            sharpe_ratio = 0

        # Drawdown
        peak = np.max(self.returns)
        drawdown = peak - self.returns[-1]

        # 정규화된 Sharpe Ratio와 Drawdown
        normalized_sharpe = np.tanh(sharpe_ratio)  # -1에서 1 사이로 정규화
        normalized_drawdown = np.tanh(drawdown)  # -1에서 1 사이로 정규화

        # 스케일링 팩터
        sharpe_scale = 0.6
        drawdown_scale = 0.6

        # 보상 함수에 샤프 비율과 드로우다운 포함
        stability_bonus = sharpe_scale * normalized_sharpe - drawdown_scale * normalized_drawdown
        total_reward += stability_bonus

        # Update returns
        self.returns.append(total_reward)

        if not self.done:
            self.current_step += 1
            self.state = np.array([df.iloc[self.current_step].values for df in self.df_list])
        else:
            self.state = np.zeros(self.observation_space.shape)  # Done 상태에서 반환할 값
            cumu_lst.append(self.total_profit)
            self.total_profit = 0

        return self.state, total_reward, self.done, {"reward": total_reward, "additional_reward": additional_reward, "sharpe_ratio": sharpe_ratio, "drawdown": drawdown, "stability_bonus": stability_bonus}

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Total Profit: {self.total_profit}, Sharpe Ratio: {np.mean(self.returns) / np.std(self.returns) if len(self.returns) > 1 else 0}, Drawdown: {(self.max_balance - self.balance) / self.max_balance}')


class EvalCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(EvalCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.action_distribution = []
        self.state_visit_frequency = {}
        self.cumulative_rewards = []  # 누적 보상을 저장하기 위한 리스트

    def _on_step(self) -> bool:
        # Record current step action for action distribution analysis
        actions = self.locals["actions"].flatten()  # Flatten actions to 1D
        self.action_distribution.extend(actions)
        
        # Record state visit frequency
        state_str = str(self.locals["new_obs"])
        if state_str in self.state_visit_frequency:
            self.state_visit_frequency[state_str] += 1
        else:
            self.state_visit_frequency[state_str] = 1
        return True

    def _on_rollout_end(self) -> None:
        # Log the reward and length for each episode
        episode_reward = sum(self.locals["rewards"])
        episode_length = len(self.locals["rewards"])
        self.episode_rewards.append(episode_reward)
        self.episode_lengths.append(episode_length)
        self.cumulative_rewards.append(sum(self.episode_rewards))  # 누적 보상을 추가
        self.logger.record('rollout/episode_reward', np.sum(self.episode_rewards))
        self.logger.record('rollout/episode_length', np.sum(self.episode_lengths))

    def _on_training_end(self) -> None:
        # Save evaluation results to file or print them
        print(f"Mean episode reward: {np.mean(self.episode_rewards)}")
        print(f"Mean episode length: {np.mean(self.episode_lengths)}")
        print(f"Cumulative reward: {np.sum(self.episode_rewards)}")

        # Plot action distribution
        plt.figure(figsize=(12, 6))
        plt.hist(self.action_distribution, bins=3, align='left', rwidth=0.8)
        plt.xticks(range(3), ['Buy', 'Hold', 'Sell'])
        plt.xlabel('Actions')
        plt.ylabel('Frequency')
        plt.title('Action Distribution')
        plt.show()

        # Plot episode rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.episode_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Episode Reward')
        plt.title('Episode Reward over Episodes')
        plt.show()

        # Plot cumulative rewards
        plt.figure(figsize=(12, 6))
        plt.plot(self.cumulative_rewards)
        plt.xlabel('Episode')
        plt.ylabel('Cumulative Reward')
        plt.title('Cumulative Reward over Episodes')
        plt.show()

        # Plot state visit frequency
        state_visit_sorted = sorted(self.state_visit_frequency.items(), key=lambda item: item[1], reverse=True)
        states, visits = zip(*state_visit_sorted)
        plt.figure(figsize=(12, 6))
        plt.bar(states[:10], visits[:10])
        plt.xlabel('States')
        plt.ylabel('Visit Frequency')
        plt.title('Top 10 Most Visited States')
        plt.show()


# 학습 환경 설정
train_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[0] for ticker in tickers]
test_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[1] for ticker in tickers]

train_env = DummyVecEnv([lambda: StockTradingEnv(train_df_list)])

# CUDA 사용 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log_dir = "/ppo_stock_trading_v11"
os.makedirs(log_dir, exist_ok=True)
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# PPO 모델 학습
from stable_baselines3.common.callbacks import CheckpointCallback

# 체크포인트 저장 콜백 설정 (예: 10000 타임스텝마다 저장)
checkpoint_callback = CheckpointCallback(save_freq=20000, save_path='./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/', name_prefix='ppo_stock_trading')

# PPO 모델 학습
model = PPO('MlpPolicy', train_env, verbose=1, device=device)
model.set_logger(new_logger)
model.learn(total_timesteps=400000, callback=[checkpoint_callback, EvalCallback()])

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df_list)])

# 학습된 모델로 예측 및 결과 시각화
obs = test_env.reset()
total_rewards = 0
total_additional_rewards = 0
total_stability_bonus = 0

for _ in range(len(test_df_list[0])):
    action, _states = model.predict(obs)
    obs, rewards, done, info = test_env.step(action)
    total_rewards += info[0]['reward']
    total_additional_rewards += info[0]['additional_reward']
    total_stability_bonus += info[0]['stability_bonus']
    test_env.render()
    if done:
        break

print(f"Final Balance: {test_env.get_attr('balance')[0]}")
print(f"Total Profit: {test_env.get_attr('total_profit')[0]}")
print(f"Total Rewards: {total_rewards}")
print(f"Total Additional Rewards: {total_additional_rewards}")
print(f"Total Stability Bonus: {total_stability_bonus}")
print(f"profit: {total_rewards - total_additional_rewards - total_stability_bonus}")
# Out:
# Logging to /ppo_stock_trading_v11
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    episode_length  | 1        |
# |    episode_reward  | 19.2     |
# | time/              |          |
# |    fps             | 273      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 2            |
# |    episode_reward       | 27           |
# | time/                   |              |
# |    fps                  | 208          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0058414307 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.000181     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+04      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 2.79e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 3           |
# |    episode_reward       | 31.9        |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 3           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006862653 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | -0.00016    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 7.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 4           |
# |    episode_reward       | 34.2        |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 4           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008211393 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | -0.000163   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.51e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 7.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 5           |
# |    episode_reward       | 59          |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 5           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.029401746 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 7.99e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 4.1e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 6            |
# |    episode_reward       | 76           |
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 6            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0079934625 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 3.93e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.02e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00611     |
# |    value_loss           | 1.1e+04      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 7           |
# |    episode_reward       | 109         |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 7           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.021819472 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 3.59e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 3.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 8           |
# |    episode_reward       | 111         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 8           |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006187958 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 6.02e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.49e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 1.49e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 9            |
# |    episode_reward       | 118          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 9            |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0063870633 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 2.98e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 1.79e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 10          |
# |    episode_reward       | 117         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 10          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007839883 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 5.28e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 782         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000322   |
# |    value_loss           | 1.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 11          |
# |    episode_reward       | 121         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 11          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009317485 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.0112      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 622         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 792         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 12          |
# |    episode_reward       | 120         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 12          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005232513 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.00149     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.01e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000964   |
# |    value_loss           | 2.39e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 13          |
# |    episode_reward       | 118         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 13          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013248949 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.00584     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 868         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 1.46e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 14           |
# |    episode_reward       | 124          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 14           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0077572344 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0107       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 3.7e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 15          |
# |    episode_reward       | 123         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 15          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006299376 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.00738     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 635         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00411    |
# |    value_loss           | 2.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 16          |
# |    episode_reward       | 123         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 16          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007631912 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.0227      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 942         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0062     |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 17          |
# |    episode_reward       | 123         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 17          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005475541 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.0211      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.22e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00609    |
# |    value_loss           | 5.17e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 18           |
# |    episode_reward       | 150          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 18           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0034277816 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.00655      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.13e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 1.41e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 19          |
# |    episode_reward       | 149         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 19          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007894088 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.00326     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.39e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 1.08e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 20           |
# |    episode_reward       | 190          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 20           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0047410782 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.0052       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000799    |
# |    value_loss           | 5.62e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 21           |
# |    episode_reward       | 190          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 21           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0075793536 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0104       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+04     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 2.26e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 22          |
# |    episode_reward       | 193         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 22          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008124285 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.00795     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.54e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 2.16e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 23           |
# |    episode_reward       | 196          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 23           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0065520266 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.00524      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 2.36e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 24          |
# |    episode_reward       | 196         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 24          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005844714 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.0727      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 386         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 588         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 25          |
# |    episode_reward       | 221         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 25          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009721361 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.0521      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 679         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00552    |
# |    value_loss           | 804         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 26          |
# |    episode_reward       | 224         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 26          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009630483 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.00716     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00648    |
# |    value_loss           | 3.32e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 27           |
# |    episode_reward       | 225          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 27           |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0060229264 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.00834      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.06e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 1.73e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 28          |
# |    episode_reward       | 224         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 28          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006991633 |
# |    clip_fraction        | 0.00913     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.0102      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 2.17e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 29          |
# |    episode_reward       | 232         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 29          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008754209 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.0157      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9e+03     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 4.17e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 30           |
# |    episode_reward       | 236          |
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 30           |
# |    time_elapsed         | 381          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0075580184 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0.0358       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 663          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00507     |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 31          |
# |    episode_reward       | 235         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 31          |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011907205 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0493      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00773    |
# |    value_loss           | 2.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 32          |
# |    episode_reward       | 230         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 32          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007167321 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.0517      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 833         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 33           |
# |    episode_reward       | 230          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 33           |
# |    time_elapsed         | 420          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0046951724 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0655       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 2.83e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 34          |
# |    episode_reward       | 234         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 34          |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006681741 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.0309      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.74e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 8.62e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 35          |
# |    episode_reward       | 319         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 35          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009163486 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.0139      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 3.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 36          |
# |    episode_reward       | 335         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 36          |
# |    time_elapsed         | 454         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007105167 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.00663     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 6.15e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 37          |
# |    episode_reward       | 335         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 37          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008520165 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | -0.00031    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+04       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 3.33e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 38          |
# |    episode_reward       | 334         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 38          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008792727 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.00268     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 39          |
# |    episode_reward       | 358         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 39          |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006690319 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.0247      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 40          |
# |    episode_reward       | 357         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 40          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013657188 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.0359      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 4.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 41          |
# |    episode_reward       | 357         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 41          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012339003 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.0402      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 399         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 788         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 42          |
# |    episode_reward       | 360         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 42          |
# |    time_elapsed         | 532         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006587771 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.0168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 758         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 43          |
# |    episode_reward       | 362         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 43          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008132021 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.0281      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 968         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 1.44e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 44           |
# |    episode_reward       | 361          |
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 44           |
# |    time_elapsed         | 557          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0050927857 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.0332       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.006       |
# |    value_loss           | 3.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 45           |
# |    episode_reward       | 361          |
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 45           |
# |    time_elapsed         | 569          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0047462853 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.012        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 2.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 46          |
# |    episode_reward       | 361         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 46          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006508776 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.0184      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 47           |
# |    episode_reward       | 362          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 47           |
# |    time_elapsed         | 592          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0057091485 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | -0.0225      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00346     |
# |    value_loss           | 3.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 48          |
# |    episode_reward       | 361         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 48          |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005492925 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.0177      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 1.71e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 49           |
# |    episode_reward       | 360          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 49           |
# |    time_elapsed         | 617          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0075131673 |
# |    clip_fraction        | 0.0761       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.0302       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00534     |
# |    value_loss           | 3.44e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 50          |
# |    episode_reward       | 360         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 50          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011330428 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.0377      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.29e+03    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 1.82e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 51           |
# |    episode_reward       | 359          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 51           |
# |    time_elapsed         | 644          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0083106775 |
# |    clip_fraction        | 0.0853       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.0223       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 468          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00832     |
# |    value_loss           | 1.36e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 52          |
# |    episode_reward       | 359         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 52          |
# |    time_elapsed         | 656         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007490247 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.0298      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51e+03    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 3.77e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 53           |
# |    episode_reward       | 362          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 53           |
# |    time_elapsed         | 668          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0074090855 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.0625       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 773          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 54           |
# |    episode_reward       | 362          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 54           |
# |    time_elapsed         | 681          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0059282756 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.0379       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 852          |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 2.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 55           |
# ...
# | rollout/                |              |
# |    episode_length       | 180          |
# |    episode_reward       | 895          |
# | time/                   |              |
# |    fps                  | 185          |
# |    iterations           | 180          |
# |    time_elapsed         | 1982         |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0077049886 |
# |    clip_fraction        | 0.0848       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0119       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.05e+03     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 4.18e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 181         |
# |    episode_reward       | 894         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 181         |
# |    time_elapsed         | 1992        |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.009200014 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0357      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 961         |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 2.96e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    episode_length       | 182       |
# |    episode_reward       | 894       |
# | time/                   |           |
# |    fps                  | 185       |
# |    iterations           | 182       |
# |    time_elapsed         | 2004      |
# |    total_timesteps      | 372736    |
# | train/                  |           |
# |    approx_kl            | 0.0053562 |
# |    clip_fraction        | 0.0275    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.22     |
# |    explained_variance   | 0.0353    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.71e+03  |
# |    n_updates            | 1810      |
# |    policy_gradient_loss | -0.00182  |
# |    value_loss           | 9.8e+03   |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 183          |
# |    episode_reward       | 893          |
# | time/                   |              |
# |    fps                  | 185          |
# |    iterations           | 183          |
# |    time_elapsed         | 2015         |
# |    total_timesteps      | 374784       |
# | train/                  |              |
# |    approx_kl            | 0.0049781576 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0282       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.53e+03     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 1.39e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 184          |
# |    episode_reward       | 945          |
# | time/                   |              |
# |    fps                  | 185          |
# |    iterations           | 184          |
# |    time_elapsed         | 2026         |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0047566085 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.0442       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+03     |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 4.48e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 185         |
# |    episode_reward       | 943         |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 185         |
# |    time_elapsed         | 2037        |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.004343358 |
# |    clip_fraction        | 0.00996     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0506      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33e+03    |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.000996   |
# |    value_loss           | 1.31e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 186         |
# |    episode_reward       | 959         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 186         |
# |    time_elapsed         | 2046        |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.008077671 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0345      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.27e+03    |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 1.57e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 187          |
# |    episode_reward       | 963          |
# | time/                   |              |
# |    fps                  | 186          |
# |    iterations           | 187          |
# |    time_elapsed         | 2056         |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0057043023 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0205       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06e+03     |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 1.03e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 188         |
# |    episode_reward       | 957         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 188         |
# |    time_elapsed         | 2065        |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.009906098 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.04        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+04    |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 2.51e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 189         |
# |    episode_reward       | 956         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 189         |
# |    time_elapsed         | 2074        |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.008716561 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0749      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.04e+03    |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 6.86e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 190          |
# |    episode_reward       | 956          |
# | time/                   |              |
# |    fps                  | 186          |
# |    iterations           | 190          |
# |    time_elapsed         | 2083         |
# |    total_timesteps      | 389120       |
# | train/                  |              |
# |    approx_kl            | 0.0067633996 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.0508       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.91e+03     |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 3.79e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 191          |
# |    episode_reward       | 957          |
# | time/                   |              |
# |    fps                  | 187          |
# |    iterations           | 191          |
# |    time_elapsed         | 2091         |
# |    total_timesteps      | 391168       |
# | train/                  |              |
# |    approx_kl            | 0.0047278544 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0883       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28e+03     |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 3.73e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 192         |
# |    episode_reward       | 957         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 192         |
# |    time_elapsed         | 2099        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.008528948 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0473      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64e+03    |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 193         |
# |    episode_reward       | 956         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 193         |
# |    time_elapsed         | 2107        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.010345838 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.0584      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24e+03    |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 3.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 194         |
# |    episode_reward       | 956         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 194         |
# |    time_elapsed         | 2115        |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.004120225 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.0424      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.98e+03    |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 6.4e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    episode_length       | 195          |
# |    episode_reward       | 955          |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 195          |
# |    time_elapsed         | 2123         |
# |    total_timesteps      | 399360       |
# | train/                  |              |
# |    approx_kl            | 0.0042198184 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.0179       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09e+03     |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 2.88e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    episode_length       | 196         |
# |    episode_reward       | 955         |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 196         |
# |    time_elapsed         | 2132        |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.010300688 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0589      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 2.9e+03     |
# -----------------------------------------
# Mean episode reward: 4.873844712128036
# Mean episode length: 1.0
# Cumulative reward: 955.273563577095
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Balance: 100000
# Total Profit: 0
# Total Rewards: 963.414290876035
# Total Additional Rewards: 45.20000000000012
# Total Stability Bonus: -252.64580891644653
# profit: 1170.8600997924814

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 데이터프레임을 70% 훈련 세트와 30% 테스트 세트로 분할
train_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[0] for ticker in tickers]
test_df_list = [train_test_split(combined_df[[col for col in combined_df.columns if ticker in col]], test_size=0.3, shuffle=False)[1] for ticker in tickers]

# 테스트 환경 설정
test_env = DummyVecEnv([lambda: StockTradingEnv(test_df_list)])

# 체크포인트 디렉토리 설정
checkpoint_dir = './Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/'
checkpoint_files = [os.path.join(checkpoint_dir, f) for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]

results = []

# 각 체크포인트 평가
for checkpoint_file in checkpoint_files:
    model = PPO.load(checkpoint_file, env=test_env)

    obs = test_env.reset()
    total_rewards = 0
    total_additional_rewards = 0
    total_stability_bonus = 0
    done = False

    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = test_env.step(action)
        total_rewards += info[0]['reward']
        total_additional_rewards += info[0]['additional_reward']
        total_stability_bonus += info[0]['stability_bonus']

    results.append({
        'checkpoint': checkpoint_file,
        'total_rewards': total_rewards,
        'total_profit': total_rewards - total_additional_rewards - total_stability_bonus,
        'total_additional_rewards': total_additional_rewards,
        'total_stability_bonus': total_stability_bonus,
    })

# 결과 출력
for result in results:
    print(f"Checkpoint: {result['checkpoint']}")
    print(f"Total Rewards: {result['total_rewards']}")
    print(f"Total Additional Rewards: {result['total_additional_rewards']}")
    print(f"Total Stability Bonus: {result['total_stability_bonus']}")
    print(f"Total Profit: {result['total_profit']}")
    print("="*50)
# Out:
# C:\Users\cmvv5\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_100000_steps.zip
# Total Rewards: -590.4544098244763
# Total Additional Rewards: 44.30000000000012
# Total Stability Bonus: -331.6240120278453
# Total Profit: -303.1303977966311
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_120000_steps.zip
# Total Rewards: 1022.567155594211
# Total Additional Rewards: 45.40000000000017
# Total Stability Bonus: -281.47269502224293
# Total Profit: 1258.6398506164537
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_140000_steps.zip
# Total Rewards: 505.63108264348267
# Total Additional Rewards: 46.60000000000016
# Total Stability Bonus: -302.85866879084335
# Total Profit: 761.889751434326
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_160000_steps.zip
# Total Rewards: 1412.1804395993536
# Total Additional Rewards: 47.80000000000015
# Total Stability Bonus: -285.03976074854637
# Total Profit: 1649.4202003478997
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_180000_steps.zip
# Total Rewards: 1892.0422040491676
# Total Additional Rewards: 47.400000000000155
# Total Stability Bonus: -251.4377939671891
# Total Profit: 2096.0799980163565
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_200000_steps.zip
# Total Rewards: 716.867843171403
# Total Additional Rewards: 45.60000000000016
# Total Stability Bonus: -263.4922352587732
# Total Profit: 934.760078430176
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_20000_steps.zip
# Total Rewards: -72.72977334443564
# Total Additional Rewards: 45.30000000000015
# Total Stability Bonus: -300.53000604096894
# Total Profit: 182.50023269653315
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_220000_steps.zip
# Total Rewards: 747.8514996557085
# Total Additional Rewards: 49.400000000000134
# Total Stability Bonus: -284.02852658940895
# Total Profit: 982.4800262451174
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_240000_steps.zip
# Total Rewards: 1819.1345185308899
# Total Additional Rewards: 47.90000000000014
# Total Stability Bonus: -263.1253027886897
# Total Profit: 2034.3598213195794
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_260000_steps.zip
# Total Rewards: -977.2498997242441
# Total Additional Rewards: 46.20000000000014
# Total Stability Bonus: -314.4698849232192
# Total Profit: -708.980014801025
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_280000_steps.zip
# Total Rewards: 133.8772614520384
# Total Additional Rewards: 46.70000000000012
# Total Stability Bonus: -268.9329375225711
# Total Profit: 356.1101989746094
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_300000_steps.zip
# Total Rewards: -646.8223268636431
# Total Additional Rewards: 46.40000000000013
# Total Stability Bonus: -296.1821771749221
# Total Profit: -397.04014968872104
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_320000_steps.zip
# Total Rewards: 1181.252361406384
# Total Additional Rewards: 45.20000000000012
# Total Stability Bonus: -287.3074026927375
# Total Profit: 1423.3597640991213
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_340000_steps.zip
# Total Rewards: 201.4622642642853
# Total Additional Rewards: 45.70000000000013
# Total Stability Bonus: -278.6178321712625
# Total Profit: 434.38009643554767
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_360000_steps.zip
# Total Rewards: 2329.134129227959
# Total Additional Rewards: 43.80000000000012
# Total Stability Bonus: -263.0459481341027
# Total Profit: 2548.3800773620615
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_380000_steps.zip
# Total Rewards: -249.01592593723632
# Total Additional Rewards: 46.20000000000011
# Total Stability Bonus: -279.29617190891605
# Total Profit: -15.91975402832037
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_400000_steps.zip
# Total Rewards: -416.47328404458887
# Total Additional Rewards: 44.10000000000011
# Total Stability Bonus: -296.2032050040619
# Total Profit: -164.37007904052706
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_40000_steps.zip
# Total Rewards: 2846.0656034350272
# Total Additional Rewards: 43.70000000000015
# Total Stability Bonus: -246.67458058596938
# Total Profit: 3049.0401840209965
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_60000_steps.zip
# Total Rewards: -422.82865484397763
# Total Additional Rewards: 43.6000000000001
# Total Stability Bonus: -300.6786662880696
# Total Profit: -165.7499885559081
# ==================================================
# Checkpoint: ./Multi_management_AAPL_SCHW_MSFT/Checkpoint_0.1/ppo_stock_trading_80000_steps.zip
# Total Rewards: -170.63801352207622
# Total Additional Rewards: 44.100000000000165
# Total Stability Bonus: -288.0881035489319
# Total Profit: 73.3500900268555
# ==================================================
